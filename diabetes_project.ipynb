# %% [markdown]
# <a href="https://colab.research.google.com/github/nafissa1-web/nafissa/blob/main/diabetes_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1418733466.py in <cell line: 0>()
#       2
#       3 with open('model.pkl', 'wb') as file:
# ----> 4     pickle.dump(diabetes_project, file)
#       5
#       6 from google.colab import files
#
# NameError: name 'diabetes_project' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset= pd.read_csv('/content/diabetes.csv')
dataset
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
# ...

# %%
dataset.describe()
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 520 non-null    int64
#  1   Gender              520 non-null    object
#  2   Polyuria            520 non-null    object
#  3   Polydipsia          520 non-null    object
#  4   sudden weight loss  520 non-null    object
#  5   weakness            520 non-null    object
#  6   Polyphagia          520 non-null    object
#  7   Genital thrush      520 non-null    object
#  8   visual blurring     520 non-null    object
#  9   Itching             520 non-null    object
#  10  Irritability        520 non-null    object
#  11  delayed healing     520 non-null    object
#  12  partial paresis     520 non-null    object
#  13  muscle stiffness    520 non-null    object
#  14  Alopecia            520 non-null    object
# ...

# %%
dataset.iloc[67, 0]= np.nan #raw10 column4
dataset.iloc[15, 4]= np.nan
dataset.iloc[7, 4]= np.nan
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 519 non-null    float64
#  1   Gender              520 non-null    object
#  2   Polyuria            520 non-null    object
#  3   Polydipsia          520 non-null    object
#  4   sudden weight loss  518 non-null    object
#  5   weakness            520 non-null    object
#  6   Polyphagia          520 non-null    object
#  7   Genital thrush      520 non-null    object
#  8   visual blurring     520 non-null    object
#  9   Itching             520 non-null    object
#  10  Irritability        520 non-null    object
#  11  delayed healing     520 non-null    object
#  12  partial paresis     520 non-null    object
#  13  muscle stiffness    520 non-null    object
#  14  Alopecia            520 non-null    object
# ...

# %%
dataset.Gender.replace({'Female':1, 'Male':0}, inplace = True)
dataset
# Out:
# /tmp/ipython-input-2942046080.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset.Gender.replace({'Female':1, 'Male':0}, inplace = True)
# /tmp/ipython-input-2942046080.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
dataset.hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Gender'}>]], dtype=object)

# %%
dataset.Age.fillna(dataset.Age.mean(), inplace= True)
dataset.dropna(inplace= True)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 518 entries, 0 to 519
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 518 non-null    float64
#  1   Gender              518 non-null    int64
#  2   Polyuria            518 non-null    object
#  3   Polydipsia          518 non-null    object
#  4   sudden weight loss  518 non-null    object
#  5   weakness            518 non-null    object
#  6   Polyphagia          518 non-null    object
#  7   Genital thrush      518 non-null    object
#  8   visual blurring     518 non-null    object
#  9   Itching             518 non-null    object
#  10  Irritability        518 non-null    object
#  11  delayed healing     518 non-null    object
#  12  partial paresis     518 non-null    object
#  13  muscle stiffness    518 non-null    object
#  14  Alopecia            518 non-null    object
# ...
